# %%
from ipynb.fs.full.main import lowercase_text, removing_numbers, remove_symbols, remove_extra_spaces, remove_stopwords, stemming
import re

# %% [markdown]
# Test lowercase_text

# %%
text = "Hello WORLD"
result = lowercase_text(text)
assert result == "hello world"
print("if error - test failed")

# %%
text = 123
result = lowercase_text(text)
assert result == 124
print("if error - test failed")

# %% [markdown]
# Test removing_numbers

# %%
text = "Article 2024 year"
result = removing_numbers(text)
assert result == "Article  year"
print("if error - test failed")

# %%
text = "No numbers here"
result = removing_numbers(text)
assert result == "No numbers here"
print("if error - test failed")

# %% [markdown]
# Test remove_symbols

# %%
text = "Hello, world!!!"
result = remove_symbols(text)
assert result == "Hello world"
print("if error - test failed")

# %%
text = "Simple text"
result = remove_symbols(text)
assert result == "Simple text"
print("if error - test failed")

# %% [markdown]
# Test remove_extra_spaces

# %%
text = "Hello    world   "
result = remove_extra_spaces(text)
assert result == "Hello world"
print("if error - test failed")

# %%
text = "Hello world"
result = remove_extra_spaces(text)
assert result == "Hello world"
print("if error - test failed")
